# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahendra8rathnayake/Coding-Temple/blob/main/Copy_of_Data_Science_Day_3_Matplotlib_class_lecture_Updated2021_Rangers59.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Science Visualization - Matplotlib

# %% [markdown]
# ## Tasks Today:
#
# 1) <b>Matplotlib</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Data Visulation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Different Types of Charts <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Basics <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Customization <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Axis Labels & Line Marks <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Legend & Line Labels <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Subplots <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Presentation Worthiness <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Box Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Scatter Plot <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; k) Histograms <br>

# %% [markdown]
# ### Data Visualization <br>
# <p>Data visualization is one of the most powerful tools an analyst has for two main reasons. Firstly, it is unrivalled in it's ability to guide the analysts hand in determining 'what to look at next'. Often a visual is revealing of patterns in the data that are not easily discernable by just looking at dataframes. Secondly, they are an analysts greatest communication tool. Very often professional analysts need to present their results to groups of people responsible for taking action based on what the data says. Visuals can tell your story much better then raw numbers, so let's talk a little bit about how to make effective visuals that make a point.</p>

# %% [markdown]
# ##### Importing

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # standard

# %% [markdown]
# ### Different Types of Charts <br>
# <ul>
#     <li><b>Line Chart:</b> Exploring data over time</li>
#     <li><b>Bar Chart:</b> Comparing categories of data and tracks changes over time</li>
#     <li><b>Pie Chart:</b> Explore parts of a whole, i.e. fractions</li>
#     <li><b>Scatter Plot:</b> Similar to line charts, track correlations between two categories</li>
#     <li><b>Histogram:</b> Unrelated from bar charts, show distribution of variables</li>
#     <li><b>Candlestick Chart:</b> Used a lot in financial sector, i.e. can compare a stock over a period of time</li>
#     <li><b>Box Chart:</b> Looks identical to candlestick charts, compares minimum, 1st, medium, 3rd quartiles, and max values</li>
# </ul>
#
# <p>Depending on what you need to accomplish in conceptualizing your data, you will go with a specific type of chart to portray your data.</p>

# %% [markdown]
# ### Basics <br>
# <p>Plots can be as detailed as you'd like them to be, but the simplest plot to start with can be done in just a few lines:</p>

# %%
plt.plot(12, 12, 9,9,6,4.,4,10)
plt.show()
plt.plot([1,2,3,4,5], [23,45,67,78,89], 'yo-') # Y- for sollid dash line representing y
plt.plot([3,4,5,6,7,8], [22,33,90,105,110,120], 'rx:') # 'Colon' for dotted line with x
plt.xlabel('Increase Value')
plt.ylabel('Decrease Value')
plt.show()

# %% [markdown]
# ### Customization <br>
# <p>There's many customizable options when using Matplotlib, such as; line types, colors, labels, figure size, etc. We'll go over a few of them here:</p>

# %% [markdown]
# ##### Axis Labels & Line Marks

# %%
plt.plot(12, 12, 9,9,6,4.,4,10)
plt.show()
import matplotlib.pyplot as plt # Import the pyplot module and give it the alias "plt"
plt.plot([1,2,3,4,5], [23,45,67,78,90], 'yo-') # Plot the first line
plt.plot([3,4,5,6,7,8], [22,33,89,105,110,120], 'rx=') # Plot the second line with the label 'rx='
plt.xlabel('Increase Value') # Set the label for the x-axis
plt.ylabel('Decrease Value') # Set the label for the y-axis
plt.show() # Display the plot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-d3b5df258473> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt # Import the pyplot module and give it the alias "plt"
#       4 plt.plot([1,2,3,4,5], [23,45,67,78,90], 'yo-') # Plot the first line
# ----> 5 plt.plot([3,4,5,6,7,8], [22,33,89,105,110,120], 'rx=') # Plot the second line with the label 'rx='
#       6 plt.xlabel('Increase Value') # Set the label for the x-axis
#       7 plt.ylabel('Decrease Value') # Set the label for the y-axis
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
#    1687         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
#    1690             self.add_line(line)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     309                 this += args[0],
#     310                 args = args[1:]
# --> 311             yield from self._plot_args(
#     312                 this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     313
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     452             # xy is tup with fmt stripped (could still be (y,) only)
#     453             *xy, fmt = tup
# --> 454             linestyle, marker, color = _process_plot_format(
#     455                 fmt, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#     456         elif len(tup) == 3:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in _process_plot_format(fmt, ambiguous_fmt_datakey)
#     196             i += 2
#     197         else:
# --> 198             raise ValueError(
#     199                 errfmt.format(fmt, f"unrecognized character {c!r}"))
#     200
#
# ValueError: 'rx=' is not a valid format string (unrecognized character '=')

# %% [markdown]
# ##### Legend & Line Labels

# %%
plt.plot([1600, 1700, 1800, 1900, 2000, 2100], [1, 2, 3, 4, 5, 6], 'ro-', label= 'first Demographic') # Removed extra elements from y-values to match x-values length
plt.plot([1600, 1700, 1800, 1900, 2000, 2100], [2,2,3,3.1,2.4, 3], 'gx-', label = 'Second Demographic') # Added an element to y-values to match x-values length
plt.xlabel('population (Billions)')
plt.ylabel('Year')
plt.legend()
plt.show()
# legend repors: specially good for written report or explaining something

# %% [markdown]
# ### Subplots <br>
# <p>Using the subplots method, you're able to create multiple plots within a single cell.</p>

# %%
# first plot=
plot_1 = plt.subplot(2,1,1) # 2 rows, 1 colum, 1 st panel in the plot
plt.plot([1600, 1700, 1800, 1900, 2000], [1, 1.4, 1.6, 1.8, 2], 'ro-', label = 'First Demographic') # Corrected the keyword argument from 'lebel' to 'label'
plot_1.set_xlim(1600,2100) # Lower - Upper bound values
plot_1.set_ylim(0,3)
plt.ylabel('Population (Billions)') # Changed 'ylable' to 'ylabel'
plt.xlabel('Year') # Changed 'xlable' to 'xlabel'
plt.legend()


# second plot
plot_2 = plt.subplot(2,1,2)
plt.plot([1600, 1700, 1800,1900, 2000], [2,2,3,3.1,2.4],'gx-', label = 'Second Demographic') # Changed 'lable' to 'label'
plot_2.set_xlim(1725,2190)
plot_2.set_ylim(0,4)
plt.ylabel('Population (Billions)') # Changed 'ylable' to 'ylabel'
plt.xlabel('Year') # Changed 'xlable' to 'xlabel'
plt.legend()
plt.show()

# %% [markdown]
# ### In-Class Exercise #1 - Create a Graph that Depicts y = f(x)

# %%
import numpy as np

# use matplotlib to plot f(x)
x_axis = np.linspace(0, 10, 50)
y_axis = x_axis ** 2

plt.plot(x_axis, y_axis)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Presentation Worthiness
# <p>Before we go into how to use this as a tool for data exploration, let's talk quickly about presentation-worthiness. In the next cell we're going to introduce customization of lines, colors, ticks, titles, fonts, and grids.</p>

# %%
fig, ax = plt.subplots(figsize = (20, 10))

plt.plot(x_axis ** 2, y_axis ** 4,
        lw = 5, # Line Width
        ls = '--', # Line Style
        color = 'r', # Line Color
        marker = "*", #Pointer Marker
        markersize = 15, # Marker size
        markerfacecolor = 'b', # Marker Color
        label = 'Data'
        )

plt.xlabel(r'$x$ Value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel(r'$y$ Value', fontname = 'Times New Roman', fontsize = 32)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title('Quadratic Equation Visual', fontname = "Times New Roman", fontsize = 40, y = 1.05)

plt.grid(True)

plt.legend(loc = 'upper left', fontsize = 40)

plt.tight_layout()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %% [markdown]
# <p>It's sometimes nice to obsess a little bit over how your plots look. It's good practice paying attention to detail and it has huge payoff when you end up presenting your findings to other analysts and business parteners. Here's a more complex example of using the matplotlib api:</p>

# %%
markers = ['o', 'v', '^', '*', 's']
styles = ['-', '--', '-.', ':', '-']
colors = ['#588C7E', '#F2E394', '#F2AE72', '#D96459', '#8C4646']

# %%
x = np.linspace(0, 10, 50)

for i in range(5):
    plt.plot(x, x ** i,
            lw = 5,
            ls = styles[i],
            color = colors[i],
            marker = markers[i],
            markersize = 15,
            markerfacecolor = colors[i],
            label = r'$x^{%s}$' % i # f'{i}'
            )

plt.xlim(0,10, 50)
plt.ylim(0,100)

plt.xlabel(r'$x$ Value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel(f'y Value', fontname = 'Times New Roman', fontsize = 32)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title(r'$y = f(x) = x^2$', fontname = "Times New Roman", fontsize = 40, y = 1.05)

plt.grid(True)

plt.legend(loc = 'upper left', fontsize = 40)

plt.tight_layout()
# Out:
# <ipython-input-47-149c8c284db6>:14: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,10, 50)
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %% [markdown]
# ### In-Class Exercise #2 - Customize the f(x) Plot Created Earlier <br>
# <p>Customize it however you would like...</p>

# %%
# students to do...
x = np.linspace(5, 10, 15)

for i in range(5):
    plt.plot(x, x ** i,
            lw = 7,
            ls = styles[i],
            color = colors[i],
            marker = markers[i],
            markersize = 20,
            markerfacecolor = colors[i],
            label = r'$x^{%s}$' % i # f'{i}'
            )

plt.xlim(0,10, 15)
plt.ylim(0,30)

plt.xlabel(r'$x$ Value', fontname = 'Times New Roman', fontsize = 32)
plt.ylabel(f'y Value', fontname = 'Times New Roman', fontsize = 32)

plt.xticks(fontsize = 28)
plt.yticks(fontsize = 28)

plt.title(r'$y = f(x) = x^2$', fontname = "Times New Roman", fontsize = 40, y = 1.05)

plt.grid(True)

plt.legend(loc = 'upper left', fontsize = 40)

plt.tight_layout()
# Out:
# <ipython-input-49-2f9aec448331>:15: MatplotlibDeprecationWarning: Passing the emit parameter of set_xlim() positionally is deprecated since Matplotlib 3.6; the parameter will become keyword-only two minor releases later.
#   plt.xlim(0,10, 15)
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %% [markdown]
# *italicized text*### Scatter Plot

# %%
import csv
from itertools import groupby
import matplotlib.pyplot as plt # Import the matplotlib library

data_fiel = '/gdrive/MyDrive/iris.csv'
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive

data_file = '/gdrive/MyDrive/iris.csv'
plt.figure(figsize = (10.5, 7.25))

def read_csv(filename):
    with open(filename, 'r') as f:
        data = list(csv.reader(f))
    return data

flowers = read_csv(data_file)
colors = {
    'Iris-setosa': '#2B5B84',
    'Iris-versicolor': 'g',
    'Iris-virginica': 'purple'
}

for species, group in groupby(flowers, lambda x: x[4]):
    flower_cat = list(group)
    sepal_length = [float(row[0]) for row in flower_cat]
    petal_width = [float(row[1]) for row in flower_cat]
    plt.scatter(sepal_length, petal_width, s = 10,  c = colors[species], label = species)
plt.title('Iris Dat Set: Sepal Length x Width', fontsize =16)
plt.xlabel('sepal Length (cm)', fontsize = 10)
plt.ylabel('petal Width (cm)', fontsize = 10)
plt.legend(loc = 'best').get_frame().set_color('chocolate')
plt.show()
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
import matplotlib.pyplot as plt # Import the matplotlib library and give it the alias 'plt'
import numpy as np

fig, ax = plt.subplots(figsize=(16, 9)) #Subplots makes a call in the background to create a plot area



# generate random data
data = np.random.uniform(0,10,100)

# %% [markdown]
# ### Histograms <br>
# <p>While line plots are great for visualizing trends in time series data, histograms are the king of visualizing distributions. Often, the distribution of a variable is what you're interested in, and a visualization provides a lot more information than a group of summary statistics.</p>

# %%
import matplotlib.pyplot as plt # Import the matplotlib library and give it the alias 'plt'
import numpy as np

fig, ax = plt.subplots(figsize=(16, 9)) #Subplots makes a call in the background to create a plot area
# generate random data
data = np.random.uniform(0,10,100)

# plot histogram
plt.hist(data, bins = 75, label = 'Data', color = 'r', alpha = 0.75)
plt.xticks(fontsize = 30)
plt.yticks(fontsize = 30)

plt.xlabel('Value', fontsize = 35, fontname = 'Times New Roman')
plt.ylabel('Frequency', fontsize = 35, fontname = 'Times New Roman')
plt.legend(loc = 'upper left', fontsize = 30) # Change 'Upper left' to 'upper left'

plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.

# %% [markdown]
# ### Box Plot

# %% [markdown]
# <p>Let's take a look at a mystery/randomly generated DataFrame, and plot the results</p>

# %%
from itertools import groupby

plt.figure(figsize = (10.5, 7.25))

fig = plt.figure()
flowers = read_csv(data_file)

petal_length = []
for species, group in groupby(flowers, lambda x: x[4]):
    petal_length.append([float(petal[2]) for petal in group])

plt.boxplot(petal_length)
plt.axis([0, 5, 0, 10]) # x min, x max, y min, y max
plt.xticks([1, 2, 3], ['setosa', 'versicolor', 'virginica'])
plt.title('Box Plot With Iris Data,set', fontsize = 16, loc = 'right')
plt.xlabel('Flower Variety', fontsize = 10)
plt.xlabel('Species:Flower Variety')
plt.ylabel('Petal Length (cm)')
plt.show()

# Save the figure as a png file to your devices ( it can save your time!)
# fig.savefig('files/iris_petal_length_data.png')

# %%
import pandas as pd
import numpy as np

def make_mystery_dataframe():
    customer_id = np.random.randint(1000,1200,10000)

    states = {1: 'California', 0: 'Colorado'}
    statelist = []
    agelist = []

    for i in range(10000):
        ind = np.random.randint(0,2)
        if ind == 0:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc = 30, scale = 10))
        elif ind == 1:
            statelist.append(states[ind])
            agelist.append(np.random.normal(loc = 40, scale = 20))

    mystery_df = pd.DataFrame.from_dict({
        'customer_id': customer_id,
        'ages':agelist,
        'state': statelist
    })

    return mystery_df

df = make_mystery_dataframe()
df.head(20)
# Out:
#     customer_id       ages       state
# 0          1055  43.015999    Colorado
# 1          1081  55.253392  California
# 2          1192  91.650375  California
# 3          1180  36.436710    Colorado
# 4          1002  56.180937  California
# 5          1024  23.953174    Colorado
# 6          1113  42.462043  California
# 7          1096  29.518048  California
# 8          1124  38.361098    Colorado
# 9          1023  35.328473    Colorado
# 10         1192  81.171272  California
# 11         1023  83.883590  California
# 12         1061  31.302968    Colorado
# 13         1111  62.649302  California
# 14         1079  16.980844    Colorado
# 15         1042  38.693220  California
# 16         1191  35.338983    Colorado
# 17         1080  31.928472    Colorado
# 18         1073  34.210794    Colorado
# 19         1161  52.855718  California

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

# First subplot - Histogram
ax1.hist(df[df['state'] == 'California']['ages'], bins = 89, label = 'Ages in Cali') # Use square brackets [] for indexing and filtering.
ax1.set_xlabel('Value', fontsize = 35, fontname = 'Times New Roman') # Correct the typo 'set_xlablel' to 'set_xlabel'.
ax1.set_ylabel('Frequency', fontsize = 35, fontname = 'Times New Roman')
ax1.legend(loc = 'upper right', fontsize = 30)
ax1.tick_params(axis = 'both', labelsize = 30)

# Second subplot - Box Plot
ax2.boxplot([df[df['state'] == 'California']['ages'], df[df['state'] == 'Colorado']['ages']]) # Use square brackets [] for indexing and filtering.
ax2.set_xticklabels(['California', 'Colorado'])
ax2.set_xlabel('State', fontsize = 35, fontname = 'Times New Roman')
ax2.set_ylabel('Ages', fontsize = 35, fontname = 'Times New Roman')
ax2.tick_params(axis = 'both', labelsize = 30)

# Third subplot
ax1.hist(df[df['state'] == 'Colorado']['ages'], bins = 89, label = 'Ages in Colorado') # Use square brackets [] for indexing and filtering.
ax1.set_xlabel('Value', fontsize = 35, fontname = 'Times New Roman') # Correct the typo 'set_xlablel' to 'set_xlabel'.
ax1.set_ylabel('Frequency', fontsize = 35, fontname = 'Times New Roman')
ax1.legend(loc = 'upper right', fontsize = 30)
ax1.tick_params(axis = 'both', labelsize = 30)


plt.tight_layout()
plt.show()

# fig.savefig('files/mystery_data.png')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Times New Roman' not found.
